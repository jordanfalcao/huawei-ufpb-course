# %% [markdown]
# # Modelo de regressão para uma fução conhecida em TensorFlow.Keras
#
# ### Nesse exemplo, vamos construir um modelo de predição para uma função matemática conhecida, de modo que possamos predizer um, ou mais, valores, a partir dos N valores anteriores dessa função. Utilizaremos para isso a função seno, e usaremos o conjunto TensorFlow keras para simplificar o processo de implementação desse exemplo.

# %% [markdown]
# ## Inicialmente vamos inserir algumas bibliotecas no nosso projeto

# %%
#importantdo as bibliotecas necessárias
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## O Segundo passo é criar a base de dados necessária para o desenvolvimento do problema

# %% [markdown]
# #### Os Dados precisam ser organizados de modo que a entrada e a saida da rede representem a dinâmica do problema.

# %%
# criação da função utilizada na informação e predição
def ProcessData(dado, intervalo_informacao, tamanho_predicao):
  '''
  dado = Conjunto de amostras usadas para o treinamento da rede
  intervalo_informação = Corresponde a quantidade de amostras que serão usadas para predição
  tamanho_predição = Corresponde a quantidade de amostras a serem preditas
  '''
  aux_a=np.zeros([len(dado)-(intervalo_informacao+tamanho_predicao),intervalo_informacao])
  aux_b=np.zeros([len(dado)-(intervalo_informacao+tamanho_predicao),tamanho_predicao])

  for i in range(len(dado)-(intervalo_informacao+tamanho_predicao)):
    aux_a[i] = dado[i:(i+intervalo_informacao)]
    aux_b[i] = dado[(i+intervalo_informacao):((i+intervalo_informacao)+tamanho_predicao)]

  return [aux_a,aux_b]

# %% [markdown]
# #### Vamos definir algumas variáveis auxiliares e o conjunto de de dados de entrada e saída do problema, para treinamento e teste.

# %%
#criando o conjunto de dados para ser usados
freq = 60
num_periodos = 15

x1=np.linspace(0,num_periodos/freq,1000)
y1=(np.sin(2*np.pi*freq*x1)+1)/2
x2=x1[0:200]
y2=(np.sin(2*np.pi*freq*x2)+1)/2

# %%
# pré processamento de dados
[entrada_train, saida_train] = ProcessData(y1, 100, 10)
[entrada_test, saida_test] = ProcessData(y2, 100, 10)
print(saida_test.shape)

plt.figure(figsize=(15,6),dpi=110)
plt.plot(y1)
plt.plot(y2,'r')
plt.show()

entrada_train = tf.convert_to_tensor(entrada_train)
saida_train = tf.convert_to_tensor(saida_train)
entrada_test = tf.convert_to_tensor(entrada_test)
saida_test = tf.convert_to_tensor(saida_test)
#print(entrada_train.shape)
#print(saida_train.shape)
saida_train
# Out:
# (90, 10)
# <tf.Tensor: shape=(890, 10), dtype=float64, numpy=
# array([[0.49528296, 0.44820492, 0.40158753, ..., 0.189574  , 0.15403057,
#         0.12156412],
#        [0.44820492, 0.40158753, 0.3558454 , ..., 0.15403057, 0.12156412,
#         0.09246343],
#        [0.40158753, 0.3558454 , 0.31138537, ..., 0.12156412, 0.09246343,
#         0.0669873 ],
#        ...,
#        [0.04734575, 0.06936509, 0.09521442, ..., 0.27279463, 0.3157623 ,
#         0.36036856],
#        [0.06936509, 0.09521442, 0.12466385, ..., 0.3157623 , 0.36036856,
#         0.40621667],
#        [0.09521442, 0.12466385, 0.15745145, ..., 0.36036856, 0.40621667,
#         0.45289888]])>

# %% [markdown]
# ### Uma vez criada a base de dados, vamos construir um modelo para regressão dos dados baseado em RNAs.

# %%
# definindo o modelo
model = keras.Sequential([
    keras.Input(shape=(100,)),  # input layer (1)  não se mexe nesta camada
    keras.layers.Dense(20, activation='relu'),  # hidden layer (1)  activation pode ser 'relu', 'sigmoid'...
    keras.layers.Dense(10, activation='relu'),  # hidden layer (2)  mexe-se apenas nas hidden layers (quantidade de neurônios e tipo de função de ativação)
    keras.layers.Dense(10, activation='relu') # output layer   não se mexe nesta camada
])

# compilando o modelo
model.compile(optimizer='adam',   # otimizador 'adam'
              loss='mse',        # função de perda MSE - Mean Squared Error
              metrics=['accuracy'])

model.summary()

# O treinamento da rede é realizado usando o módulo fit e recebe como um dos 
# parâmetros a quantidade de iterações desejadas de minimização do erro.
model.fit(entrada_train, saida_train, shuffle=True, epochs=100)
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 20)                2020
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                210
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                110
# =================================================================
# Total params: 2,340
# Trainable params: 2,340
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2392 - accuracy: 0.3090
# Epoch 2/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1869 - accuracy: 0.2517
# Epoch 3/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1507 - accuracy: 0.2528
# Epoch 4/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1341 - accuracy: 0.2315
# Epoch 5/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1156 - accuracy: 0.4640
# Epoch 6/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1115 - accuracy: 0.6292
# Epoch 7/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1105 - accuracy: 0.7652
# Epoch 8/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1078 - accuracy: 0.8135
# Epoch 9/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0803 - accuracy: 0.4719
# Epoch 10/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0746 - accuracy: 0.6022
# Epoch 11/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0737 - accuracy: 0.7472
# Epoch 12/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0734 - accuracy: 0.7921
# Epoch 13/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0733 - accuracy: 0.8101
# Epoch 14/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0733 - accuracy: 0.8292
# Epoch 15/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0732 - accuracy: 0.8427
# Epoch 16/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0732 - accuracy: 0.8551
# Epoch 17/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0732 - accuracy: 0.8730
# Epoch 18/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0732 - accuracy: 0.8854
# Epoch 19/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0732 - accuracy: 0.8854
# Epoch 20/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0732 - accuracy: 0.9000
# Epoch 21/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0732 - accuracy: 0.9045
# Epoch 22/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0732 - accuracy: 0.9135
# Epoch 23/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9124
# Epoch 24/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9157
# Epoch 25/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9191
# Epoch 26/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9180
# Epoch 27/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9247
# Epoch 28/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9315
# Epoch 29/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9315
# Epoch 30/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9360
# Epoch 31/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9438
# Epoch 32/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9483
# Epoch 33/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9506
# Epoch 34/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9483
# Epoch 35/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9528
# Epoch 36/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9551
# Epoch 37/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9629
# Epoch 38/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9618
# Epoch 39/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9607
# Epoch 40/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9640
# Epoch 41/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9584
# Epoch 42/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9584
# Epoch 43/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9640
# Epoch 44/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9596
# Epoch 45/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9652
# Epoch 46/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9607
# Epoch 47/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9663
# Epoch 48/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9685
# Epoch 49/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9652
# Epoch 50/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9663
# Epoch 51/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9697
# Epoch 52/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9697
# Epoch 53/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 54/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 55/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9697
# Epoch 56/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 57/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 58/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 59/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9697
# Epoch 60/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 61/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 62/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 63/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 64/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 65/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 66/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 67/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 68/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 69/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 70/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 71/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 72/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 73/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 74/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 75/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 76/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 77/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 78/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 79/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 80/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 81/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 82/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 83/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 84/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 85/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 86/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 87/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 88/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 89/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 90/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 91/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 92/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 93/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 94/100
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 95/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 96/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 97/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 98/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 99/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708
# Epoch 100/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9708

# %% [markdown]
# ### Uma vez treinada essa rede pode ser testada para avaliação de seu desempenho

# %%
test_loss, test_acc = model.evaluate(entrada_test,  saida_test, verbose=1) 

print('Test accuracy:', test_acc)
# Out:
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0282 - accuracy: 0.9889
# Test accuracy: 0.9888888597488403

# %% [markdown]
# ### Considerando o problema proposto devemos separar os dados para o treinamento de acordo com as restrições impostas no problema. Vamos usar um conjunto com 100 amostras de entrada para predizer as proximas 10 amostras de saída do sistema.

# %%
# realizando uma predição
predictions = model.predict(entrada_test)

plt.figure(figsize=(15,6),dpi=110)
plt.plot(predictions[:,0],'*b')  
plt.plot(saida_test[:,0],'r')
plt.ylim([0,1.2])
plt.legend(['Dado Estimado','Dado Real'])
plt.show()
